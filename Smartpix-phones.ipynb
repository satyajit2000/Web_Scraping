# %%
import numpy as np
import pandas as pd

# %%
with open('smartpix.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html,'lxml')

# %%
soup.prettify()
# Out:
# '<html class="way-item-finder" lang="en" style="--window-width:1536;">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width" name="viewport"/>\n  <title>\n   Mobile Phones In Stock | Smartprix\n  </title>\n  <link href="/sm-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>\n  <meta content="#4692F0" name="theme-color"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <meta content="171761809591603" property="fb:app_id"/>\n  <link href="https://www.smartprix.com/mobiles/exclude_out_of_stock-exclude_upcoming-stock" rel="canonical"/>\n  <meta content="Smartprix" property="og:site_name"/>\n  <meta content="@smartprix" name="twitter:site"/>\n  <meta content="@smartprix" name="twitter:creator"/>\n  <meta content="summary" name="twitter:card"/>\n  <link href="/smartprix_search.xml" rel="search" title="Smartprix Search: Find the best price" type="application/opensearchdescription+xml"/>\n  <script type="application/ld+json">\n   {"@type":"Organization","@context":"http://schema.org/","@id":"https://www.smartprix.com#organization","name":"Smartprix","url":"https://www.smartprix.com","sameAs":["https://www.facebook.com/smartprix","https://www.instagram.com/smartprix/","https://www.linkedin.com/company/smartprix/","https://plus.google.com/102248368379090638322","https://www.pinterest.com/smartprixcom/","https://twitter.com/smartprix","https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q","https://t.me/Smartprix_Deals"],"logo":"https://www.smartprix.com/smartprix.png"}\n  </script>\n  <script type="application/ld+json">\n   {"@type":"Website","@context":"http://schema.org/","@id":"https://www.smartprix.com#website","url":"https://www.smartprix.com","potentialAction":{"@type":"SearchAction","target":"https://www.smartprix.com/products/?q={search_term}","query-input":"required name=search_term"}}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Mobile Phones","item":"https://www.smartprix.com/mobiles"},{"@type":"ListItem","position":2,"name":"Mobile Phones In Stock","item":"https://www.smartprix.com/mobiles/exclude_out_of_stock-stock"}]}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"ItemList","itemListElement":[{"@type":"ListItem","additionalType":"Product","position":1,"name":"OnePlus 11 5G","url":"https://www.smartprix.com/mobiles/oneplus-11-5g-ppd12268zbmr","image":["https://cdn1.smartprix.com/rx-iab0UrrCY-w1200-h1200/ab0UrrCY.webp"]},{"@type":"ListItem","additionalType":"Product","position":2,"name":"OnePlus Nord CE 2 Lite 5G","url":"https://www.smartprix.com/mobiles/oneplus-nord-ce-2-lite-5g-ppd1dhnh78au","image":["https://cdn1.smartprix.com/rx-iGNlyOFEo-w1200-h1200/GNlyOFEo.webp"]},{"@type":"ListItem","additionalType":"Product","position":3,"name":"Oppo Reno 8T","url":"https://www.smartprix.com/mobiles/oppo-reno-8t-ppd1lcqaairf","image":["https://cdn1.smartprix.com/rx-ilZR4kBqK-w1200-h1200/lZR4kBqK.webp"]},{"@type":"ListItem","additionalType":"Product","position":4,"name":"Motorola Moto G62 5G","url":"https://www.smartprix.com/mobiles/motorola-moto-g62-5g-ppd1av8pgu0a","image":["https://cdn1.smartprix.com/rx-iCDx5JIUn-w1200-h1200/CDx5JIUn.webp"]},{"@type":"ListItem","additionalType":"Product","position":5,"name":"Samsung Galaxy A14 5G","url":"https://www.smartprix.com/mobiles/samsung-galaxy-a14-ppd1tpcg7uoq","image":["https://cdn1.smartprix.com/rx-ixLSVBm6G-w1200-h1200/xLSVBm6G.webp"]},{"@type":"ListItem","additionalType":"Product","position":6,"name":"Realme 10 Pro Plus","url":"https://www.smartprix.com/mobiles/realme-10-pro-plus-5g-ppd1yrm4oyml","image":["https://cdn1.smartprix.com/rx-iKWyXqzam-w1200-h1200/KWyXqzam.webp"]},{"@type":"ListItem","additionalType":"Product","position":7,"name":"Apple iPhone 14","url":"https://www.smartprix.com/mobiles/app ...

# %%
containers = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
name = []
price = []
rating = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []
for i in containers:
    try:
        name.append(i.find('h2').text)
    except:
        name.append(np.nan)
    try:
        price.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        rating.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        rating.append(np.nan)
    
    x=i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(name)
# Out:
# 1020

# %%
df = pd.DataFrame({
    'model':name,
    'price':price,
    'rating':rating,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                           model    price rating  \
# 0     OnePlus Nord CE 2 Lite 5G  ₹18,999     81
# 1          Motorola Moto G62 5G  ₹14,999     81
# 2         Samsung Galaxy A14 5G  ₹16,499     75
# 3            Realme 10 Pro Plus  ₹24,999     82
# 4               Apple iPhone 14  ₹72,999     81
# ...                         ...      ...    ...
# 1015              Kechaoda K107   ₹1,499    NaN
# 1016             Eunity U1 1282     ₹638    NaN
# 1017              Eunity U1 310     ₹619    NaN
# 1018            Eunity U1 Pulse     ₹699    NaN
# 1019           Karbonn KX51 Pro   ₹1,349    NaN
#
#                                           sim  \
# 0          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                       ...
# 1015                                 Dual Sim
# 1016                                 Dual Sim
# 1017                                 Dual Sim
# 1018                                 Dual Sim
# 1019                                 Dual Sim
#
#                                           processor                       ram  \
# 0      Snapdragon 695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 1     Snapdragon  695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 2         Exynos 1330, Octa Core, 2.4 GHz Processor   4 GB RAM, 64 GB inbuilt
# 3      Dimensity 1080, Octa Core, 2.6 GHz Processor  6 GB RAM, 128 GB inbuilt
# 4         Bionic A15, Hexa Core, 3.22 GHz Processor  6 GB RAM, 128 GB inbuilt
# ...                                             ...                       ...
# 1015                      32 MB RAM, 128 MB inbuilt          3000 mAh Battery
# 1016                             1.77 MHz Processor  32 MB RAM, 32 MB inbuilt
# 1017                             1.77 MHz Processor  32 MB RAM, 32 MB inbuilt
# 1018                             1.77 MHz Processor  16 MB RAM, 16 MB inbuilt
# 1019                              1.1 MHz Processor  32 MB RAM, 32 MB inbuilt
#
#                                       battery  \
# 0     5000 mAh Battery with 33W Fast Charging
# 1         5000 mAh Battery with Fast Charging
# 2     5000 mAh Battery with 15W Fast Charging
# 3     5000 mAh Battery with 67W Fast Charging
# 4         3279 mAh Battery with Fast Charging
# ...                                       ...
# 1015         2.4 inches, 240 x 320 px Display
# 1016                         1000 mAh Battery
# 1017                         1000 mAh Battery
# 1018                         3000 mAh Battery
# 1019                         1800 mAh Battery
#
#                                                 display  \
# 0     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 1     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 4     6.1 inches, 1170 x 2532 px Display with Small ...
# ...                                                 ...
# 1015                                 0.3 MP Rear Camera
# 1016                   1.8 inches, 176 x 220 px Display
# 1017                   1.8 inches, 176 x 220 px Display
# 1018                   1.8 inches, 176 x 220 px Display
# 1019                   2.4 inches, 240 x 320 px Display
#
#                                                  camera  \
# 0     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 4          12 MP + 12 MP Dual Rear & 12 MP Front Camera
# ...                                                 ...
# 1015                  Memory Card Supported, upto 16 GB
# 1016                                 0.3 MP Rear Camera
# 1017                                 0.3 MP Rear Camera
# 1018                                 0.3 MP Rear Camera
# 1019                                 0.3 MP Rear Camera
#
#                                    card           os
# 0       Memory Card (Hybrid), upto 1 TB  Android v12
# 1       Memory Card (Hybrid), upto 1 TB  Android v12
# 2      Memory Card Supported, upto 1 TB  Android v13
# 3             Memory Card Not Supported  Android v13
# 4             Memory Card Not Supported      iOS v16
# ...                                 ...          ...
# 1015                          Bluetooth          NaN
# 1016  Memory Card Supported, upto 16 GB          NaN
# 1017  Memory Card Supported, upto 16 GB          NaN
# 1018                                NaN          NaN
# 1019  Memory Card Supported, upto 32 GB          NaN
#
# [1020 rows x 11 columns]

# %%
df.to_csv('smartpix_phones.csv')
